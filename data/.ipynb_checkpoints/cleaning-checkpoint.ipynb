# %%
import pandas as pd

# %%
file_path = "./womenDressesReviewsDataset.csv"
df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#    s.no  age   division_name department_name  class_name  clothing_id  \
# 0     0   40         General         Bottoms       Jeans         1028
# 1     1   62  General Petite            Tops     Blouses          850
# 2     2   47  General Petite         Bottoms      Skirts          993
# 3     3   45  General Petite         Bottoms       Pants         1068
# 4     4   37       Initmates        Intimate        Swim           24
# 5     5   43         General            Tops    Sweaters          933
# 6     6   83         General            Tops    Sweaters          937
# 7     7   34         General            Tops       Knits          868
# 8     8   49  General Petite            Tops  Fine gauge          900
# 9     9   49         General            Tops       Knits          873
#
#                         title  \
# 0        Amazing fit and wash
# 1          Lovely and unique!
# 2                         Meh
# 3                         Wow
# 4      Great for bigger busts
# ...

# %%
grouped = df.groupby('age')

# %%
print(grouped)

# %%
new_df = df[['division_name',  'age', 'class_name']].groupby('class_name').sum().reset_index()
new_df
# Out:
#         class_name                                      division_name     age
# 0          Blouses  General PetiteGeneral PetiteGeneralGeneralGene...  137050
# 1   Casual bottoms                                     GeneralGeneral      53
# 2         Chemises                                          Initmates      38
# 3          Dresses  GeneralGeneral PetiteGeneralGeneral PetiteGene...  266124
# 4       Fine gauge  General PetiteGeneralGeneral PetiteGeneralGene...   49204
# 5        Intimates  InitmatesInitmatesInitmatesInitmatesInitmatesI...    6030
# 6          Jackets  General PetiteGeneralGeneral PetiteGeneral Pet...   30845
# 7            Jeans  GeneralGeneralGeneralGeneralGeneralGeneralGene...   49454
# 8            Knits  GeneralGeneralGeneralGeneral PetiteGeneralGene...  211304
# 9         Layering  InitmatesInitmatesInitmatesInitmatesInitmatesI...    6063
# 10         Legwear  InitmatesInitmatesInitmatesInitmatesInitmatesI...    6855
# ...
